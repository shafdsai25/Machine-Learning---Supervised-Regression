# %% [markdown]
# # SLR FINAL EXAM

# %% [markdown]
# ### Data_set:
# Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present more unique, personalized way of experiencing the world. This dataset describes the listing activity and metrics in NYC, NY for 2019.

# %% [markdown]
# 1. id = listing ID
# 2. name = name of the listing
# 3. host_id = host ID
# 4. host_name = name of the host
# 5. neighbourhood_group = location
# 6. neighbourhood = area
# 7. latitude = latitude coordinates
# 8. longitude = longitude coordinates
# 9. room_type = listing space type
# 10. price = price in dollars (Target variable)
# 11. minimum_nights = amount of nights minimum
# 12. number_of_reviews = number of reviews
# 13. last_review = latest review
# 14. reviews_per_month = number of reviews per month
# 15. calculated_host_listings_count = amount of listing per host
# 16. availability_365 = number of days when listing is available for booking

# %% [markdown]
# ### 1.	 Read the dataset (tab, csv, xls, txt, inbuilt dataset)

# %%
# Kindly change the below cells from markdown to code and execute it

# %%
import numpy as np 
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
matplotlib.rcParams['font.family'] = "Arial"
import collections
import itertools
import scipy.stats as stats
from scipy.stats import norm
from scipy.special import boxcox1p
import statsmodels
import statsmodels.api as sm
#print(statsmodels.__version__)
from sklearn.preprocessing import scale, StandardScaler, RobustScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold, StratifiedKFold, RandomizedSearchCV
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV, LinearRegression, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import r2_score
from sklearn.impute import SimpleImputer
import warnings                                          # importing warnings to warn programmers about changes in language or library features
warnings.filterwarnings('ignore')                        # ignoring warnings
import random                                            # importing generating or manipulating random integers

# %%
#import Required libraries
import pandas as pd

import csv

with open("new_york_city_air.csv","r")as file:

    reader=csv.reader(file)
    
df=pd.read_csv("new_york_city_air.csv")

df.head()
# Out:
#          id                                               name    host_id  \
# 0  12598446                   Spacious 4bdrm next to CentralPk    5162192
# 1  13585495       Great room in amazing Little Italy location!   15960548
# 2  27761683  Clean Cozy Room, Queens-5 min walk to subway (...  199524563
# 3  14200678   Charming 1 bdr apt. just 17 mins from MANHATTAN!     557669
# 4  24540935                          A Beach House in Brooklyn   51068857
#
#   host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0       Amy           Manhattan     Upper West Side  40.79860  -73.96229
# 1    Nathan           Manhattan        Little Italy  40.71955  -73.99707
# 2       Bei              Queens           Rego Park  40.72678  -73.86218
# 3      Ryan              Queens            Woodside  40.74663  -73.89653
# 4     Derek            Brooklyn  Bedford-Stuyvesant  40.68297  -73.95251
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# import pandas as pd
#
# df = pd.read_csv('file.csv')
# This will read the CSV file into a DataFrame and store it in the variable df.
#
# You can also specify additional options when reading the file. For example, you can specify the delimiter if the file is not a standard CSV file, or you can specify which columns to include or exclude, or you can specify the index column. You can find more information about these options in the documentation for pandas.read_csv.

# %% [markdown]
# ### 2.	Data Understanding
# #### Summarize important observations from the data set (5 Marks)
# Some pointers which would help you, but don’t be limited by these
#
# a.	What are the number of rows; no. & types of variables (continuous, categorical etc.)
#
# b.	Calculate five point summary for numerical variables
#
# c.	Summarize observations for categorical variables – no. of categories, % observations in each category

# %% [markdown]
# a. What are the number of rows;

# %%
# Get the shape of the DataFrame
df.shape
# Out:
# (1054, 16)

# %%
df.shape[0]
# Out:
# 1054

# %% [markdown]
# no. of variables

# %%
df.shape[1]
# Out:
# 16

# %%
# Get the shape of the DataFrame
rows, columns = df.shape

# Print the number of rows and columns
print(f'The DataFrame has {rows} rows and {columns} columns.')
# Out:
# The DataFrame has 1054 rows and 16 columns.

# %% [raw]
# This will print the number of rows and columns in the DataFrame. For example, if the DataFrame has 1054 rows and 16 columns, it will print The DataFrame has 10 rows and 5 columns.

# %% [markdown]
# types of variables (continuous, categorical etc.)|

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054 entries, 0 to 1053
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              1054 non-null   int64
#  1   name                            1053 non-null   object
#  2   host_id                         1054 non-null   int64
#  3   host_name                       1054 non-null   object
#  4   neighbourhood_group             1054 non-null   object
#  5   neighbourhood                   1054 non-null   object
#  6   latitude                        1054 non-null   float64
#  7   longitude                       1054 non-null   float64
#  8   room_type                       1054 non-null   object
#  9   price                           1054 non-null   int64
#  10  minimum_nights                  1054 non-null   int64
#  11  number_of_reviews               1054 non-null   int64
# ...

# %%
no_rows = len(df)

# Count the number of columns and group them by data type
var_counts = df.dtypes.value_counts()

# Print the number and types of variables
print(f'The DataFrame has {len(df.columns)} variables:')
for dtype, count in var_counts.items():
    print(f'{count} {dtype} variables')
# Out:
# The DataFrame has 16 variables:
# 7 int64 variables
# 6 object variables
# 3 float64 variables

# %% [markdown]
# This will print information about the DataFrame, such as the number of rows and columns, the data type of each column, and the memory usage of the DataFrame.This tells us that the DataFrame has 1054 rows and 16 columns, and the data type of each column. It also shows the memory usage of the DataFrame.
# This will print the number and types of variables in the DataFrame. For example, if the DataFrame has 3 integer columns, 2 float columns, and 1 string column, it will print The DataFrame has 6 variables: 7 int64 variables, 3 float64 variables, 6 object variable.

# %%
df=df.astype({"id":'object', "host_id":'object'})
df['last_review']=pd.to_datetime(df['last_review'],infer_datetime_format=True)

# %% [markdown]
# The astype method of a Pandas DataFrame allows you to convert the data type of one or more columns of the DataFrame.

# %% [markdown]
# This will convert the data type of the 'column_name' column from its current data type to float.
#
# You can also use the astype method to convert multiple columns at once. Just pass a list of column names to the columns parameter:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054 entries, 0 to 1053
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              1054 non-null   object
#  1   name                            1053 non-null   object
#  2   host_id                         1054 non-null   object
#  3   host_name                       1054 non-null   object
#  4   neighbourhood_group             1054 non-null   object
#  5   neighbourhood                   1054 non-null   object
#  6   latitude                        1054 non-null   float64
#  7   longitude                       1054 non-null   float64
#  8   room_type                       1054 non-null   object
#  9   price                           1054 non-null   int64
#  10  minimum_nights                  1054 non-null   int64
#  11  number_of_reviews               1054 non-null   int64
# ...

# %%
# Select only the columns with the object data type
object_columns = df.select_dtypes(include=['object'])

# %%
df.dtypes.value_counts()
# Out:
# object            7
# int64             5
# float64           3
# datetime64[ns]    1
# dtype: int64

# %% [markdown]
# The value_counts method of a Pandas Series returns the counts of unique values in the Series. It is often used to get a summary of the distribution of values in a categorical or discrete-valued column.

# %% [markdown]
# categorical variables

# %%
categorical_cols = df.select_dtypes(include='object').columns.tolist()   #convert the object elements of an array into a list
categorical_cols
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'room_type']

# %% [markdown]
# In Pandas, categorical variables are represented using the category data type. You can convert a column in a Pandas DataFrame to the category data type using the astype method and specifying the 'category' data type.

# %% [markdown]
# numerical variables

# %%
numerical_cols = df.select_dtypes(include='number').columns.tolist()   #convert the object elements of an array into a list
numerical_cols
# Out:
# ['latitude',
#  'longitude',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365']

# %% [markdown]
# Numerical variables are variables that represent quantitative data, such as . Numerical variables can be either continuous or discrete. Continuous variables can take on any value within a certain range, while discrete variables can only take on a limited number of values.
# latitude',
#  'longitude',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365'
# In Pandas, numerical variables are represented using the int and float data types. The int data type is used for integer values, while the float data type is used for decimal values.

# %% [markdown]
# b. Calculate five point summary for numerical variables

# %%
# Get a summary of the numerical columns
df.describe()
# Out:
#           latitude    longitude        price  minimum_nights  \
# count  1054.000000  1054.000000  1054.000000     1054.000000
# mean     40.728377   -73.951802   149.699241        8.002846
# std       0.056092     0.049034   156.239782       34.580253
# min      40.499790   -74.240840    10.000000        1.000000
# 25%      40.689253   -73.983770    70.000000        1.000000
# 50%      40.721665   -73.956930   104.000000        3.000000
# 75%      40.761120   -73.935523   179.000000        5.000000
# max      40.898730   -73.731700  2000.000000      999.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count        1054.000000         844.000000                     1054.000000
# mean           24.620493           1.347690                        6.959203
# std            49.178939           1.675154                       31.266268
# min             0.000000           0.020000                        1.000000
# ...

# %% [markdown]
# The describe method of a Pandas DataFrame provides a summary of the central tendency, dispersion, and shape of the distribution of the values in the DataFrame.
#
# The describe method returns a new DataFrame with several columns, including:
#
# count: The number of non-missing values
# mean: The mean of the values
# std: The standard deviation of the values
# min: The minimum value
# 25%, 50%, 75%: The percentiles of the values
# max: The maximum value
# By default, the describe method only includes columns with numerical data types. However, you can specify the include parameter to include columns with other data types, such as object or bool.
# This will create a new DataFrame with a summary of all columns in the original DataFrame, regardless of data type.
#
# The describe method is a useful tool for getting a quick summary of the values in a DataFrame and identifying potential outliers or anomalies in the data.

# %% [markdown]
# c.	Summarize observations for categorical variables – no. of categories, % observations in each category

# %% [markdown]
#  Summarize observations for categorical variables

# %%
# get the summary output for categorical variable
df.describe(include = "object")
# Out:
#               id                          name    host_id host_name  \
# count       1054                          1053       1054      1054
# unique      1054                          1050       1018       779
# top     12598446  New york Multi-unit building  219517861      Alex
# freq           1                             2          6        13
#
#        neighbourhood_group neighbourhood        room_type
# count                 1054          1054             1054
# unique                   5           123                3
# top              Manhattan  Williamsburg  Entire home/apt
# freq                   449            92              539

# %% [markdown]
# no. of categories, % observations in each category

# %% [markdown]
# neighbourhood_group

# %%
df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        449
# Brooklyn         431
# Queens           130
# Bronx             34
# Staten Island     10
# Name: neighbourhood_group, dtype: int64

# %%
s = df.neighbourhood_group
counts = s.value_counts()
percent = s.value_counts(normalize=True)
percent100 = s.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'counts': counts, '%': percent, '%100': percent100})
# Out:
#                counts         %   %100
# Manhattan         449  0.425996  42.6%
# Brooklyn          431  0.408918  40.9%
# Queens            130  0.123340  12.3%
# Bronx              34  0.032258   3.2%
# Staten Island      10  0.009488   0.9%

# %% [markdown]
# This will create a new Pandas Series with the counts and percentages of observations in each category of the 'column_name' column. The index of the Series will be the unique values in the column, and the values will be the counts and percentages of those values.

# %% [markdown]
# neighbourhood

# %%
df['neighbourhood'].value_counts()
# Out:
# Williamsburg          92
# Bedford-Stuyvesant    76
# Bushwick              53
# Upper West Side       49
# Hell's Kitchen        46
#                       ..
# Tribeca                1
# Kew Gardens            1
# Morris Park            1
# Randall Manor          1
# Huguenot               1
# Name: neighbourhood, Length: 123, dtype: int64

# %%
s = df.neighbourhood
counts = s.value_counts()
percent = s.value_counts(normalize=True)
percent100 = s.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'counts': counts, '%': percent, '%100': percent100})
# Out:
#                     counts         %  %100
# Williamsburg            92  0.087287  8.7%
# Bedford-Stuyvesant      76  0.072106  7.2%
# Bushwick                53  0.050285  5.0%
# Upper West Side         49  0.046490  4.6%
# Hell's Kitchen          46  0.043643  4.4%
# ...                    ...       ...   ...
# Tribeca                  1  0.000949  0.1%
# Kew Gardens              1  0.000949  0.1%
# Morris Park              1  0.000949  0.1%
# Randall Manor            1  0.000949  0.1%
# Huguenot                 1  0.000949  0.1%
#
# [123 rows x 3 columns]

# %% [markdown]
# room_type

# %%
df['room_type'].value_counts().count()
# Out:
# 3

# %%
df['room_type'].value_counts()
# Out:
# Entire home/apt    539
# Private room       482
# Shared room         33
# Name: room_type, dtype: int64

# %%
# Calculate the percentage of observations 
s = df.room_type
counts = s.value_counts()
percent = s.value_counts(normalize=True)
percent100 = s.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'counts': counts, '%': percent, '%100': percent100})
# Out:
#                  counts         %   %100
# Entire home/apt     539  0.511385  51.1%
# Private room        482  0.457306  45.7%
# Shared room          33  0.031309   3.1%

# %% [markdown]
# ### 3.	Data Preparation
# #### Check for defects in the data. Perform necessary actions to ‘fix’ these defects (5 Marks)
# Some pointers which would help you, but don’t be limited by these
#
# a.	Do variables have missing/null values?
#
# b.	Do variables have outliers?
#
# c.	Is the data normally distributed? Is it a defect? Why or why not?

# %% [markdown]
# a. Do variables have missing/null values?

# %%
# get the count of missing values
missing_values = df.isnull().sum()

# check for missing values
total = df.isnull().sum().sort_values(ascending=False)

# calculate percentage of the missing values
percent = ((df.isnull().sum()/df.shape[0])*100)

# sort the values in descending order
# ascending: 
percent = percent.sort_values(ascending=False)

# concatenate the total missing values and percentage of the missing values
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

# add the data types
missing_data['Type'] = df[missing_data.index].dtypes

# view the missing data
missing_data
# Out:
#                                 Total    Percent            Type
# last_review                       210  19.924099  datetime64[ns]
# reviews_per_month                 210  19.924099         float64
# name                                1   0.094877          object
# id                                  0   0.000000          object
# host_id                             0   0.000000          object
# host_name                           0   0.000000          object
# neighbourhood_group                 0   0.000000          object
# neighbourhood                       0   0.000000          object
# latitude                            0   0.000000         float64
# longitude                           0   0.000000         float64
# room_type                           0   0.000000          object
# price                               0   0.000000           int64
# minimum_nights                      0   0.000000           int64
# ...

# %% [markdown]
# This will check if the 'column_name' column has any missing or null values, and print a message accordingly.The isnull method of a Pandas DataFrame returns a boolean mask indicating which values in the DataFrame are missing or null. You can then use the sum method to count the number of missing or null values in each column.

# %% [markdown]
# filling missing values in reviews_per_month

# %%
# reviews per month feature is numerical, so lets impute with mean(Handled outliers)
mean_imputer = SimpleImputer(strategy='mean')
df['reviews_per_month'] = mean_imputer.fit_transform(df['reviews_per_month'].values.reshape(-1,1))

# %% [markdown]
# filling missing values in last_review

# %%
# replace all the missing values with 'Medium'
df.last_review.replace(np.NaN,df.last_review.mode()[0] ,inplace = True)

# %% [markdown]
# filling zero values in availability_365

# %%
df.availability_365.replace(np.NaN,df.availability_365.mean() ,inplace = True)

# %%
df.last_review.mode()[0]
# Out:
# Timestamp('2019-01-07 00:00:00')

# %%
df.last_review.replace(pd.NaT,df.last_review.mode()[0] ,inplace = True)

# %% [markdown]
# b. Do variables have outliers?

# %%
# pass width and height in inches to 'figsize' 
plt.figure(figsize = (15,8))

# plot a boxplot to visualize the outliers in all the numeric variables
df.boxplot()

# set plot label
# set text size using 'fontsize'
plt.title('Distribution of all Numeric Variables', fontsize = 15)

# xticks() returns the x-axis ticks
# 'rotation = vertical' rotates the x-axis labels vertically
plt.xticks(rotation = 'vertical', fontsize = 15)

# display the plot
plt.show()

# %% [markdown]
# Outliers are values that are significantly different from the majority of the values in a dataset. Outliers can be caused by measurement errors, data entry errors, or other factors, and they can have a significant impact on statistical analyses.
#
# To check if a Pandas DataFrame has outliers, you can use various methods, such as the boxplot method,

# %% [markdown]
# removing outliers

# %%
numerical_col = df.select_dtypes(include='number')                  # selecting the numeric features to form numeric dataframe  

i = 1
for col_name in numerical_col:
    
    q1=df[col_name].quantile(0.25)
    q3=df[col_name].quantile(0.75)
    iqr=q3-q1
    ub=q3+1.5*iqr
    lb=q1-1.5*iqr
    for ind1 in df[col_name].index:
      if df[col_name].loc[ind1]>ub:
        df[col_name].loc[ind1]=ub
      elif df[col_name].loc[ind1]<lb:
        df[col_name].loc[ind1]=lb

    i +=1

# %%
# pass width and height in inches to 'figsize' 
plt.figure(figsize = (15,8))

# plot a boxplot to visualize the outliers in all the numeric variables
df.boxplot()

# set plot label
# set text size using 'fontsize'
plt.title('Distribution of all Numeric Variables', fontsize = 15)

# xticks() returns the x-axis ticks
# 'rotation = vertical' rotates the x-axis labels vertically
plt.xticks(rotation = 'vertical', fontsize = 15)

# display the plot
plt.show()

# %%
df.shape
# Out:
# (1054, 16)

# %% [markdown]
# This will calculate the interquartile range (IQR) of the 'column_name' column and use it to define the lower and upper bounds. Any values outside these bounds are considered outliers. The code will then check if any values in the column are outside the bounds, and print a message indicating whether there are any outliers or not.
#
# You can also use the boxplot method of a Pandas Series to visualize the distribution of values and identify potential outliers:

# %% [markdown]
# c. Is the data normally distributed? Is it a defect? Why or why not?

# %%
for column in numerical_col:
    sns.distplot(df[column])
    plt.show()

# %% [markdown]
# To determine if a dataset is normally distributed, you can use various methods, such as visualizing the distribution of values using a histogram or a qq plot, or calculating statistical measures such as the mean, median, and standard deviation.
#
# A normal distribution, also known as a Gaussian distribution, is a symmetric distribution with a bell-shaped curve. The mean, median, and mode of a normal distribution are all equal, and approximately 68% of the values fall within one standard deviation of the mean.
#
# If a dataset is not normally distributed, it does not necessarily mean that there is a defect in the data. Non-normal distributions are common in real-world data, and can be caused by various factors such as measurement errors, sampling biases, or underlying patterns in the data.This will create a histogram of the values in the 'column_name' column and display it using Matplotlib.
#
# You can then visually inspect the histogram to determine if the distribution of values is approximately bell-shaped and symmetric, which would indicate a normal distribution.

# %% [markdown]
# ### 4.	Summarize relationships among variables (5 marks)
# a.	Plot correlation plots. Which are the variables most correlated with Target? Which independent variables are correlated among themselves? Do you want to exclude some variables from the model based on this analysis? What other actions will you take?
#
#
# b.	Plot all independent variables with the target. Are all relationships linear? If not, what steps would you take based on this information?
#
#  Hint: based on your observations you may want to transform features or create additional features.

# %% [markdown]
# a. Plot correlation plots. Which are the variables most correlated with Target? Which independent variables are correlated among themselves? Do you want to exclude some variables from the model based on this analysis? What other actions will you take?

# %%
 #plotting the heatmap for correlation
corr = df.corr()
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# A heatmap is a graphical representation of data where the values are represented as colors. Heatmaps are often used to visualize the relationships between variables, such as correlations.
#
# To create a heatmap of correlations in a Pandas DataFrame, you can use the corr method and the heatmap function from the seaborn library.
# This will create a heatmap of the correlations between the columns in the DataFrame. The values in the heatmap will range from -1 (perfect negative correlation) to 1 (perfect positive correlation), with values closer to 0 indicating weaker correlations.
#
# You can customize the appearance of the heatmap using various parameters of the heatmap function, such as annot, cmap, or vmin and vmax.

# %% [markdown]
# price vs availability_365 are the variables most correlated with Target<br>
# number_of_reviews vs reviews_per_month are independent variables correlated among themselves

# %%
#dropping columns that are not significant or could be unethical to use for our future data exploration and predictions
df.drop(['id','name','host_name','host_id','last_review'], axis=1, inplace=True)
df.head(5)
# Out:
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           Manhattan     Upper West Side  40.79860 -73.962290
# 1           Manhattan        Little Italy  40.71955 -73.997070
# 2              Queens           Rego Park  40.72678 -73.863151
# 3              Queens            Woodside  40.74663 -73.896530
# 4            Brooklyn  Bedford-Stuyvesant  40.68297 -73.952510
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0  Entire home/apt  275.0              11                4.0
# 1     Private room  110.0               2                1.0
# 2     Private room   55.0               2               25.0
# 3  Entire home/apt   96.0               2                1.0
# 4     Private room   80.0               1                0.0
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0            0.15000                             3.5               199
# 1            0.03000                             1.0                 0
# ...

# %% [markdown]
# To drop columns from a Pandas DataFrame that are not significant, you can use the drop method.
#
# The drop method allows you to remove rows or columns from a DataFrame by specifying the indexes or labels of the rows or columns to be removed.
#
# Here's an example of how to drop columns from a DataFrame:

# %% [markdown]
# b. Plot all independent variables with the target. Are all relationships linear? If not, what steps would you take based on this information?

# %% [markdown]
# frequency encoding

# %%
# frequency encoding on 'Item_Type'
# size of each category
encoding = df.groupby('neighbourhood_group').size()

# get frequency of each category
encoding = encoding/len(df)

# encode the column
# map(): apply encoding to each item in the variable
# and multiply by 100
df['freq_enc_neighbourhood_group'] = df.neighbourhood_group.map(encoding)*100

# %%
# frequency encoding on 'Item_Type'
# size of each category
encoding = df.groupby('neighbourhood').size()

# get frequency of each category
encoding = encoding/len(df)

# encode the column
# map(): apply encoding to each item in the variable
# and multiply by 100
df['freq_enc_neighbourhood'] = df.neighbourhood.map(encoding)*100

# %%
# frequency encoding on 'Item_Type'
# size of each category
encoding = df.groupby('room_type').size()

# get frequency of each category
encoding = encoding/len(df)

# encode the column
# map(): apply encoding to each item in the variable
# and multiply by 100
df['freq_enc_room_type'] = df.room_type.map(encoding)*100

# print first five rows of the data
df.head()
# Out:
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           Manhattan     Upper West Side  40.79860 -73.962290
# 1           Manhattan        Little Italy  40.71955 -73.997070
# 2              Queens           Rego Park  40.72678 -73.863151
# 3              Queens            Woodside  40.74663 -73.896530
# 4            Brooklyn  Bedford-Stuyvesant  40.68297 -73.952510
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0  Entire home/apt  275.0              11                4.0
# 1     Private room  110.0               2                1.0
# 2     Private room   55.0               2               25.0
# 3  Entire home/apt   96.0               2                1.0
# 4     Private room   80.0               1                0.0
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0            0.15000                             3.5               199
# 1            0.03000                             1.0                 0
# ...

# %% [markdown]
# Frequency encoding is a technique used to encode categorical variables in a dataset by replacing the categories with the frequency or count of each category.

# %%
df.drop(['neighbourhood_group','neighbourhood','room_type'], axis = 1,inplace=True)

# %%
plt.figure(figsize=(24,36))
plt.subplots_adjust(wspace=1, hspace=None)
cols = df.loc[:, df.columns != 'price']

for col_name in cols:
    sns.set_style('whitegrid')
    sns.lmplot(x ='price', y = col_name , data = df)

    #df.plot(x = 'price', y =col_name, kind = 'scatter',colormap = 'magma');
    #plt.scatter(df['price'],col_name,c ="pink",linewidths = 2,marker ="s",edgecolor ="green",s = 50)

# %% [markdown]
# ## 5.	Split dataset into train and test (70:30) (1 MARKS)
#
# #### a.Are both train and test representative of the overall data? How would you ascertain this statistically?

# %%
# select the target variable
Y = df['price']

# select all the independent variables
# by dropping the target variable
X = df.drop(['price'], axis = 1)

# %%
# let us now split the dataset into train & test
# test_size: the proportion of data to be included in the testing set
xtrain,xtest,ytrain,ytest = train_test_split(X, Y, test_size = 0.30, random_state=100)

# %%
print(X.shape)
print(xtrain.shape)
print(xtest.shape)
# Out:
# (1054, 10)
# (737, 10)
# (317, 10)

# %%
print(Y.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (1054,)
# (737,)
# (317,)

# %% [markdown]
# To split a Pandas DataFrame into a training set and a test set, you can use the train_test_split function from the sklearn.model_selection module.
#
# The train_test_split function takes a DataFrame as input and returns two new DataFrames: one for the training set and one for the test set. You can specify the size of the test set using the test_size parameter.

# %% [markdown]
# To split a Pandas DataFrame into a training set and a test set, you can use the train_test_split function from the sklearn.model_selection module.
#
# The train_test_split function takes a DataFrame as input and returns two new DataFrames: one for the training set and one for the test set. You can specify the size of the test set using the test_size parameter
#
# train, test = train_test_split(df, test_size=0.2)
# This will split the DataFrame into a training set and a test set, with 70% of the rows going to the training set and 30% going to the test set.
#
# You can also specify the random_state parameter to ensure that the same split is obtained every time the code is run.

# %% [markdown]
# ###  6.	Fit a base model. Please write your key observations (14 marks)
#
# a. Fit the Linear Regression Model
#
# b. What is the overall R2? Please comment on whether it is good or not.
#
# c.	What is the adjusted R2? Is it different from R2? Why?
#
# d.	Which variables are significant?

# %% [markdown]
# a. Fit the Linear Regression Model

# %%
# filter the numerical features in the dataset
df_numeric_features_vif = X.select_dtypes(include=[np.number])

# display the first five observations
df_numeric_features_vif.head()
# Out:
#    latitude  longitude  minimum_nights  number_of_reviews  reviews_per_month  \
# 0  40.79860 -73.962290              11                4.0            0.15000
# 1  40.71955 -73.997070               2                1.0            0.03000
# 2  40.72678 -73.863151               2               25.0            2.37000
# 3  40.74663 -73.896530               2                1.0            0.03000
# 4  40.68297 -73.952510               1                0.0            1.34769
#
#    calculated_host_listings_count  availability_365  \
# 0                             3.5               199
# 1                             1.0                 0
# 2                             3.0                38
# 3                             1.0                 0
# 4                             1.0                 5
#
#    freq_enc_neighbourhood_group  freq_enc_neighbourhood  freq_enc_room_type
# 0                     42.599620                4.648956            51.13852
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# create an empty dataframe to store the VIF for each variable
vif = pd.DataFrame()

# calculate VIF using list comprehension 
# use for loop to access each variable 
# calculate VIF for each variable and create a column 'VIF_Factor' to store the values 
vif["VIF_Factor"] = [variance_inflation_factor(df_numeric_features_vif.values, i) for i in range(df_numeric_features_vif.shape[1])]

# create a column of variable names
vif["Features"] = df_numeric_features_vif.columns

# sort the dataframe based on the values of VIF_Factor in descending order
# 'ascending = False' sorts the data in descending order
# 'reset_index' resets the index of the dataframe
# 'drop = True' drops the previous index
vif.sort_values('VIF_Factor', ascending = False).reset_index(drop = True)
# Out:
#       VIF_Factor                        Features
# 0  488618.641700                       longitude
# 1  486960.693290                        latitude
# 2      35.251367              freq_enc_room_type
# 3      13.807684    freq_enc_neighbourhood_group
# 4       4.895051  calculated_host_listings_count
# 5       3.669765               reviews_per_month
# 6       2.910129          freq_enc_neighbourhood
# 7       2.648234                  minimum_nights
# 8       2.551458               number_of_reviews
# 9       2.270774                availability_365

# %% [markdown]
# In linear regression, the variance inflation factor (VIF) is a measure of multicollinearity, which is the presence of correlated predictor variables in a model. A high VIF value indicates that the predictor variables are highly correlated, which can lead to unstable and unreliable regression estimates.
#
# To calculate the VIF for each predictor variable in a linear regression model, you can use the variance_inflation_factor function from the statsmodels library.A VIF value greater than 10 is generally considered to be indicative of high multicollinearity. In such cases, you may need to remove one or more predictor variables from the model to improve its stability and reliability.

# %%
# build a model on training dataset
# fit() is used to fit the OLS model
MLR_full_model = sm.OLS(ytrain, xtrain).fit()

# print the summary output
print(MLR_full_model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.772
# Model:                            OLS   Adj. R-squared (uncentered):              0.768
# Method:                 Least Squares   F-statistic:                              245.5
# Date:                Fri, 23 Dec 2022   Prob (F-statistic):                   2.23e-225
# Time:                        21:04:18   Log-Likelihood:                         -4253.4
# No. Observations:                 737   AIC:                                      8527.
# Df Residuals:                     727   BIC:                                      8573.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# To fit an ordinary least squares (OLS) linear regression model in Python, you can use the OLS class from the statsmodels library.
#
# The OLS class allows you to fit a linear regression model using the ordinary least squares method, which estimates the coefficients of the model by minimizing the sum of the squared residuals.This will fit an OLS linear regression model using the 'predictor1', 'predictor2', and 'predictor3' columns as the predictor variables and the 'target' column as the response variable.
#
# The summary method of the OLS class returns a summary of the model fit, including the coefficients of the model, the goodness of fit measures, and the p-values of the coefficients.

# %% [markdown]
# Interpretation: The R-squared value obtained from this model is 0.3 which means that the above model explains a 30% of the variation in the price.
# The Durbin-Watson test is used to check the autocorrelation between the residuals.
#
# If the Durbin-Watson test statistic is near to 2: no autocorrelation
# If the Durbin-Watson test statistic is between 0 and 2: positive autocorrelation
# If the Durbin-Watson test statistic is between 2 and 4: negative autocorrelation
#
# The summary output shows that the value of the test statistic is far from 2 (= 2.050) which means there is autocorrelation.
#
# The Jarque-Bera test is used to check the normality of the residuals. Here, the p-value of the test is less than 1.665; that implies the residuals are not normally distributed.
#
# Also, the 'Cond. No' 2.56...(1.94e+16) represents the Condition Number (CN) that is used to check the multicollinearity.
#
# If CN < 100: no multicollinearity.
# If CN is between 100 and 1000: moderate multicollinearity
# If CN > 1000: severe multicollinearity
#
# Thus, it can be seen that there is severe multicollinearity in the data.

# %%
y_pred = MLR_full_model.predict(xtest)
y_pred
# Out:
# 311     149.508070
# 240     154.115993
# 1034    166.277001
# 562      18.684517
# 982     107.324045
#            ...
# 402     197.344572
# 737     137.064379
# 372     163.604941
# 885     165.659413
# 454     116.931295
# Length: 317, dtype: float64

# %% [markdown]
# In a machine learning or statistical model, y_pred is a variable that represents the predicted values of the response variable (also known as the target variable).

# %%
# calculate p-values for all the independent variables in the MLR_model
# create a dataframe containing p-values 
# pass the column name to the parameter 'columns'
MLR_pvalues = pd.DataFrame(MLR_full_model.pvalues, columns = ["P-Value"])

# print the dataframe
MLR_pvalues
# Out:
#                                      P-Value
# latitude                        8.904520e-01
# longitude                       9.224614e-01
# minimum_nights                  7.075467e-02
# number_of_reviews               1.443469e-06
# reviews_per_month               1.717453e-01
# calculated_host_listings_count  5.155501e-01
# availability_365                1.998106e-07
# freq_enc_neighbourhood_group    3.648212e-13
# freq_enc_neighbourhood          2.563249e-04
# freq_enc_room_type              6.060393e-21

# %%
# subset the dataframe 'MLR_pvalues' such that the variables will have p-value greater than 0.05
# store the subset of a dataframe to a new dataframe 'insignificant_var' 
insignificant_var = MLR_pvalues[1:][MLR_pvalues[1:]['P-Value'] > 0.05]

# get the variable names with p-value greater than 0.05
insigni_var = insignificant_var.index

# convert the variables to the type 'list' using 'to_list()'
insigni_var = insigni_var.to_list()

# print the list of insignificant variables
insigni_var
# Out:
# ['longitude',
#  'minimum_nights',
#  'reviews_per_month',
#  'calculated_host_listings_count']

# %%
# drop the insignificant variables from the dataframe 'X_train_signi_var'
# 'axis = 1' drops the corresponding column(s)
xtrain = xtrain.drop(insigni_var, axis=1)

# drop the insignificant variables from the dataframe 'X_test_signi_var'
# 'axis = 1' drops the corresponding column(s)
xtest = xtest.drop(insigni_var, axis=1)

# building a model on training dataset
# fit() is used to fit the OLS model
MLR_model_with_significant_var = sm.OLS(ytrain, xtrain).fit()

# print the summary output
print(MLR_model_with_significant_var.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.769
# Model:                            OLS   Adj. R-squared (uncentered):              0.768
# Method:                 Least Squares   F-statistic:                              406.6
# Date:                Fri, 23 Dec 2022   Prob (F-statistic):                   5.09e-229
# Time:                        21:05:55   Log-Likelihood:                         -4256.8
# No. Observations:                 737   AIC:                                      8526.
# Df Residuals:                     731   BIC:                                      8553.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Assumptions After MLR Model
# Linear Relationship Between Dependent and Independent Variable
# Autocorrelation
# Heteroscedasticity
# Tests of Normality

# %% [markdown]
# Linear Relationship

# %%
# create subplots of scatter plots
# pass the number of rows in a subplot to 'nrows'
# pass the number of columns in a subplot to 'ncolumns'
# set plot size using 'figsize'
fig, ax = plt.subplots(nrows = 2, ncols= 2, figsize=(20, 15))

# use for loop to create scatter plot for residuals and each independent variable (do not consider the intercept)
# 'ax' assigns axes object to draw the plot onto 
for variable, subplot in zip(xtrain.columns[1:5], ax.flatten()):
    sns.scatterplot(xtrain[variable], MLR_model_with_significant_var.resid , ax=subplot)

# display the plot
plt.show()

# %% [markdown]
# Interpretation: The above plots show no specific pattern, implies that there is a linearity present in the data.

# %% [markdown]
# Autocorrelation

# %%
# print the model summary
print(MLR_model_with_significant_var.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.769
# Model:                            OLS   Adj. R-squared (uncentered):              0.768
# Method:                 Least Squares   F-statistic:                              406.6
# Date:                Fri, 23 Dec 2022   Prob (F-statistic):                   5.09e-229
# Time:                        21:06:00   Log-Likelihood:                         -4256.8
# No. Observations:                 737   AIC:                                      8526.
# Df Residuals:                     731   BIC:                                      8553.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# From the above summary, we can observe that the value obtained from the Durbin-Watson test statistic is
#  2.046. Thus, we conclude that there is no autocorrelation.

# %% [markdown]
# Heteroskedasticity

# %%
import statsmodels.stats.api as sms
from statsmodels.compat import lzip

# create vector of result parmeters
name = ['f-value','p-value']

# perform Breusch-Pagan test using residuals and independent variables
# compute residuals using 'resid'
# 'exog' returns the independent variables in the model alng with the intercept
test = sms.het_breuschpagan(MLR_model_with_significant_var.resid, MLR_model_with_significant_var.model.exog)

# print the output
# use 'lzip' to zip the column names and test results
# use 'test[2:]' to retrieve the F-statistic and its corresponding p-value 
lzip(name, test[2:])
# Out:
# [('f-value', 71.5476354890593), ('p-value', 4.285488053388622e-70)]

# %% [markdown]
# Heteroskedasticity is a statistical term that refers to the presence of unequal variances in a dataset. In other words, it is the situation where the variance of a variable is not constant across the levels of another variable.
#
# In a linear regression model, heteroskedasticity can lead to biased and inconsistent estimates of the model coefficients and incorrect inference about the statistical significance of the coefficients.
#
# To detect heteroskedasticity in a linear regression model, you can use statistical tests such as the Breusch-Pagan test or the White test. These tests compare the residual variance of the model to the predicted values of the response variable, and provide a p-value indicating whether the variance is constant or not.
#
# To correct for heteroskedasticity in a linear regression model, you can use techniques such as weighted least squares regression or generalized least squares regression. These techniques estimate the model by minimizing a different loss function that takes into account the unequal variances of the data.

# %% [markdown]
# We observe that the p-value is greater than 0.05; thus, we conclude that there is no heteroskedasticity present in the data.

# %% [markdown]
# Tests for Normality

# %%
from statsmodels.graphics.gofplots import qqplot
# set the plot size using 'rcParams'
# once the plot size is set using 'rcParams', it sets the size of all the forthcoming plots in the file
# pass width and height in inches to 'figure.figsize' 
plt.rcParams['figure.figsize'] = [15,8]

# plot the Q-Q plot
# 'r' represents the regression line
qqplot(MLR_model_with_significant_var.resid, line = 'r')

# set plot and axes labels
# set text size using 'fontsize'
plt.title('Q-Q Plot', fontsize = 15)
plt.xlabel('Theoretical Quantiles', fontsize = 15)
plt.ylabel('Sample Quantiles', fontsize = 15)

# display the plot
plt.show()

# %%
# import various functions from scipy
from scipy import stats
from scipy.stats import shapiro
# perform Shapiro Wilk test using 'shapiro()' from scipy library
# shapiro() returns a tuple having the values of test statistics and the corresponding p-value
# 'resid' returns the residuals in the model
# pass the residuals to 'shapiro()'
stat, p_value = shapiro(MLR_model_with_significant_var.resid)

# print the test statistic and corresponding p-value 
print('Test statistic:', stat)
print('P-Value:', p_value)
# Out:
# Test statistic: 0.9310734868049622
# P-Value: 6.457930563918883e-18

# %% [markdown]
# From the above test we can see that the p-value is 0.4 (greater than 0.05), thus we can say that the residuals are  normally distributed.

# %%
r_sq_mlr = MLR_model_with_significant_var.rsquared

# print the value
r_sq_mlr
# Out:
# 0.769429006851492

# %% [markdown]
# In a machine learning or statistical model, the R-squared value, also known as the coefficient of determination, is a measure of the goodness of fit of the model. It indicates the proportion of the variance in the response variable that is explained by the predictor variables.
#
# The R-squared value is a value between 0 and 1, with a higher value indicating a better fit. A model with an R-squared value of 1 means that all the variance in the response variable is explained by the predictor variables, while a model with an R-squared value of 0 means that the predictor variables have no effect on the response variable.The R-squared value is a useful measure of the fit of a linear regression model, as it indicates the proportion of the variance in the response variable that is explained by the predictor variables. However, it is important to note that a high R-squared value does not necessarily imply a good model, as other factors such as overfitting and bias can also affect the model's performance.

# %%
# calculate adjusted R-Squared on train dataset
# use 'rsquared_adj' from statsmodel
adj_r_sq = MLR_model_with_significant_var.rsquared_adj

# print the value
adj_r_sq
# Out:
# 0.7675364952798216

# %% [markdown]
# In a machine learning or statistical model, the adjusted R-squared value is a modified version of the R-squared value that takes into account the number of predictor variables in the model.
#
# The R-squared value is a measure of the goodness of fit of a model, which indicates the proportion of the variance in the response variable that is explained by the predictor variables. However, the R-squared value tends to increase as the number of predictor variables in the model increases, even if the additional predictor variables do not contribute to the fit of the model.
#
# The adjusted R-squared value is a modified version of the R-squared value that adjusts for the number of predictor variables in the model, so that the value does not increase unnecessarily as the number of predictor variables increases.

# %% [markdown]
# Model Performance

# %%
train_pred = MLR_model_with_significant_var.predict(xtrain)

# predict the output of the target variable from the test data
test_pred = MLR_model_with_significant_var.predict(xtest)

# %%
 #calculate the MSE for the train data
# round the value upto 4 digits using 'round()'
mse_train = round(mean_squared_error(ytrain, train_pred),4)

# print the MSE for the training set
print("Mean Squared Error (MSE) on training set: ", mse_train)

# calculate the MSE for the test data
# round the value upto 4 digits using 'round()'
mse_test = round(mean_squared_error(ytest, test_pred),4)

# print the MSE for the test set
print("Mean Squared Error (MSE) on test set: ", mse_test)
# Out:
# Mean Squared Error (MSE) on training set:  6087.2326
# Mean Squared Error (MSE) on test set:  6416.5846

# %% [markdown]
# The MSE is a useful measure of the fit of a linear regression model, as it provides a quantitative measure of the difference between the predicted values and the actual values. However, it is important to note that the MSE is sensitive to the scale of the response variable and can be influenced by outliers in the data.

# %% [markdown]
# Root Mean Squared Error (RMSE)

# %%
# calculate the MSE using the "mean_squared_error" function

# MSE for the train data
mse_train = mean_squared_error(ytrain, train_pred)

# take the square root of the MSE to calculate the RMSE
# round the value upto 4 digits using 'round()'
rmse_train = round(np.sqrt(mse_train), 4)

# print the RMSE for the train set
print("Root Mean Squared Error (RMSE) on training set: ", rmse_train)

# MSE for the test data
mse_test = mean_squared_error(ytest, test_pred)

# take the square root of the MSE to calculate the RMSE
# round the value upto 4 digits using 'round()'
rmse_test = round(np.sqrt(mse_test), 4)

# print the RMSE for the test set
print("Root Mean Squared Error (RMSE) on test set: ", rmse_test)
# Out:
# Root Mean Squared Error (RMSE) on training set:  78.0207
# Root Mean Squared Error (RMSE) on test set:  80.1036

# %% [markdown]
# The RMSE is a measure of the quality of the fit of a model, with a lower RMSE indicating a better fit. It is often used as a loss function in optimization algorithms, as it penalizes large errors more than small errors.

# %%
# 'metrics' from sklearn is used for evaluating the model performance
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# calculate the MAE using the "mean_absolute_error" function

# calculate the MAE for the train data
# round the value upto 4 digits using 'round()'
mae_train = round(mean_absolute_error(ytrain, train_pred),4)

# print the MAE for the training set
print("Mean Absolute Error (MAE) on training set: ", mae_train)

# calculate the MAE for the test data
# round the value upto 4 digits using 'round()'
mae_test = round(mean_absolute_error(ytest, test_pred),4)

# print the MAE for the test set
print("Mean Absolute Error (MAE) on test set: ", mae_test)
# Out:
# Mean Absolute Error (MAE) on training set:  62.3922
# Mean Absolute Error (MAE) on test set:  61.4116

# %% [markdown]
# Mean Absolute Percentage Error (MAPE)

# %%
def mape(actual, predicted):
    return (np.mean(np.abs((actual - predicted) / actual)) * 100)

# %%
# calculate the mape using the "mape()" function created above

# calculate the MAPE for the train data
# round the value upto 4 digits using 'round()'
mape_train = round(mape(ytrain, train_pred),4)

# print the MAPE for the training set
print("Mean Absolute Percentage Error (MAPE) on training set: ", mape_train)

# calculate the MAPE for the test data
# round the value upto 4 digits using 'round()'
mape_test = round(mape(ytest, test_pred),4)

# print the MAPE for the test set
print("Mean Absolute Percentage Error (MAPE) on test set: ", mape_test)
# Out:
# Mean Absolute Percentage Error (MAPE) on training set:  68.2435
# Mean Absolute Percentage Error (MAPE) on test set:  65.4131
